# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
data_frame = pd.read_csv('E:\College stuff\Sem 5\Club\Workshop 1\workshop-1\house-sales.csv')
column_data = data_frame['Area (sqft)']
plt.plot(column_data)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Area (sqft)')
plt.show()

# %%
import pandas as pd
colors = ['red', 'green', 'blue']
color_series = pd.Series(colors)
print(color_series)
# Out:
# 0      red
# 1    green
# 2     blue
# dtype: object

# %%
import pandas as pd
house_types = ['villa', 'apartment', 'bungalow']
house_series = pd.Series(house_types)
print(house_series)
# Out:
# 0        villa
# 1    apartment
# 2     bungalow
# dtype: object

# %%
import pandas as pd
colors = ['red', 'green', 'blue']
house_types = ['villa', 'apartment', 'bungalow']
color_series = pd.Series(colors, name='Color')
house_series = pd.Series(house_types, name='House Type')
combined_df = pd.concat([color_series, house_series], axis=1)
print(combined_df)
# Out:
#    Color House Type
# 0    red      villa
# 1  green  apartment
# 2   blue   bungalow

# %%
import pandas as pd
data_frame = pd.read_csv('E:\College stuff\Sem 5\Club\Workshop 1\workshop-1\house-sales.csv')
print(data_frame)
# Out:
#   Type of house Colour  Area (sqft)  Number of doors       Price
# 0     apartment  White         1100                1   $4,000.00
# 1        Duplex    Red          502                2   $5,000.00
# 2     apartment   Blue         1225                2   $7,000.00
# 3      bungalow  Black         1500                4  $22,000.00
# 4     Farmhouse  White         2020                3   $3,500.00
# 5     apartment  Green         1115                1   $4,500.00
# 6        duplex   Blue          550                2   $7,500.00
# 7        duplex   Blue          530                2   $7,000.00
# 8     Apartment  White         1200                1   $6,250.00
# 9     farmhouse  White         2504                4   $9,700.00

# %%
import pandas as pd
data_frame = pd.read_csv('E:\College stuff\Sem 5\Club\Workshop 1\workshop-1\house-sales.csv')
data_frame.to_csv('output.csv', index=False)
data_frame = pd.read_csv('E:\College stuff\Sem 5\Club\Workshop 1\workshop-1\output.csv')
print(data_frame)
# Out:
#   Type of house Colour  Area (sqft)  Number of doors       Price
# 0     apartment  White         1100                1   $4,000.00
# 1        Duplex    Red          502                2   $5,000.00
# 2     apartment   Blue         1225                2   $7,000.00
# 3      bungalow  Black         1500                4  $22,000.00
# 4     Farmhouse  White         2020                3   $3,500.00
# 5     apartment  Green         1115                1   $4,500.00
# 6        duplex   Blue          550                2   $7,500.00
# 7        duplex   Blue          530                2   $7,000.00
# 8     Apartment  White         1200                1   $6,250.00
# 9     farmhouse  White         2504                4   $9,700.00

# %%
import pandas as pd
data_frame = pd.read_csv('E:\College stuff\Sem 5\Club\Workshop 1\workshop-1\house-sales.csv')
data_types = data_frame.dtypes
print(data_types)
# Out:
# Type of house      object
# Colour             object
# Area (sqft)         int64
# Number of doors     int64
# Price              object
# dtype: object

# %%
import pandas as pd
data_frame = pd.read_csv('E:\College stuff\Sem 5\Club\Workshop 1\workshop-1\house-sales.csv')
description = data_frame.describe()
print(description)
# Out:
#        Area (sqft)  Number of doors
# count    10.000000        10.000000
# mean   1224.600000         2.200000
# std     652.620223         1.135292
# min     502.000000         1.000000
# 25%     687.500000         1.250000
# 50%    1157.500000         2.000000
# 75%    1431.250000         2.750000
# max    2504.000000         4.000000

# %%
import pandas as pd
data_frame = pd.read_csv('E:\College stuff\Sem 5\Club\Workshop 1\workshop-1\house-sales.csv')
information = data_frame.info()
print(information)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Type of house    10 non-null     object
#  1   Colour           10 non-null     object
#  2   Area (sqft)      10 non-null     int64
#  3   Number of doors  10 non-null     int64
#  4   Price            10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes
# None

# %%
import pandas as pd
numbers = [120, 130, 110, 140, 115]
number_series = pd.Series(numbers)
mean = number_series.mean()
print(mean)
# Out:
# 123.0

# %%
import pandas as pd
numbers = [120, 130, 110, 140, 115]
number_series = pd.Series(numbers)
total_sum = number_series.sum()
print(total_sum)
# Out:
# 615

# %%
import pandas as pd
data_frame = pd.read_csv('E:\College stuff\Sem 5\Club\Workshop 1\workshop-1\house-sales.csv')
columns_list = data_frame.columns.tolist()
print(columns_list)
# Out:
# ['Type of house', 'Colour', 'Area (sqft)', 'Number of doors', 'Price']

# %%
import pandas as pd
data_frame = pd.read_csv('E:\College stuff\Sem 5\Club\Workshop 1\workshop-1\house-sales.csv')
length = len(data_frame)
print(length)
# Out:
# 10

# %%
import pandas as pd
data_frame = pd.read_csv('E:\College stuff\Sem 5\Club\Workshop 1\workshop-1\house-sales.csv')
first_5_rows = data_frame.head(5)
print(first_5_rows)
# Out:
#   Type of house Colour  Area (sqft)  Number of doors       Price
# 0     apartment  White         1100                1   $4,000.00
# 1        Duplex    Red          502                2   $5,000.00
# 2     apartment   Blue         1225                2   $7,000.00
# 3      bungalow  Black         1500                4  $22,000.00
# 4     Farmhouse  White         2020                3   $3,500.00

# %%
import pandas as pd
data_frame = pd.read_csv('E:\College stuff\Sem 5\Club\Workshop 1\workshop-1\house-sales.csv')
first_7_rows = data_frame.head(7)
print(first_7_rows)
# Out:
#   Type of house Colour  Area (sqft)  Number of doors       Price
# 0     apartment  White         1100                1   $4,000.00
# 1        Duplex    Red          502                2   $5,000.00
# 2     apartment   Blue         1225                2   $7,000.00
# 3      bungalow  Black         1500                4  $22,000.00
# 4     Farmhouse  White         2020                3   $3,500.00
# 5     apartment  Green         1115                1   $4,500.00
# 6        duplex   Blue          550                2   $7,500.00

# %%
import pandas as pd
data_frame = pd.read_csv('E:\College stuff\Sem 5\Club\Workshop 1\workshop-1\house-sales.csv')
last_5_rows = data_frame.tail(5)
print(last_5_rows)
# Out:
#   Type of house Colour  Area (sqft)  Number of doors      Price
# 5     apartment  Green         1115                1  $4,500.00
# 6        duplex   Blue          550                2  $7,500.00
# 7        duplex   Blue          530                2  $7,000.00
# 8     Apartment  White         1200                1  $6,250.00
# 9     farmhouse  White         2504                4  $9,700.00

# %%
import pandas as pd
data_frame = pd.read_csv('E:\College stuff\Sem 5\Club\Workshop 1\workshop-1\house-sales.csv')
row_3 = data_frame.loc[3]
print(row_3)
# Out:
# Type of house        bungalow
# Colour                  Black
# Area (sqft)              1500
# Number of doors             4
# Price              $22,000.00
# Name: 3, dtype: object

# %%
import pandas as pd
data_frame = pd.read_csv('E:\College stuff\Sem 5\Club\Workshop 1\workshop-1\house-sales.csv')
row_3 = data_frame.iloc[3]
print(row_3)
# Out:
# Type of house        bungalow
# Colour                  Black
# Area (sqft)              1500
# Number of doors             4
# Price              $22,000.00
# Name: 3, dtype: object

# %%
import pandas as pd
data_frame = pd.read_csv('E:\College stuff\Sem 5\Club\Workshop 1\workshop-1\house-sales.csv')
column_data = data_frame['Area (sqft)']
print(column_data)
# Out:
# 0    1100
# 1     502
# 2    1225
# 3    1500
# 4    2020
# 5    1115
# 6     550
# 7     530
# 8    1200
# 9    2504
# Name: Area (sqft), dtype: int64

# %%
import pandas as pd
data_frame = pd.read_csv('E:\College stuff\Sem 5\Club\Workshop 1\workshop-1\house-sales.csv')
column_data = data_frame['Area (sqft)']
mean_value = column_data.mean()
print(mean_value)
# Out:
# 1224.6

# %%
import pandas as pd
data_frame = pd.read_csv('E:\College stuff\Sem 5\Club\Workshop 1\workshop-1\house-sales.csv')
filtered_rows = data_frame[data_frame['Area (sqft)'] > 1000]
print(filtered_rows)
# Out:
#   Type of house Colour  Area (sqft)  Number of doors       Price
# 0     apartment  White         1100                1   $4,000.00
# 2     apartment   Blue         1225                2   $7,000.00
# 3      bungalow  Black         1500                4  $22,000.00
# 4     Farmhouse  White         2020                3   $3,500.00
# 5     apartment  Green         1115                1   $4,500.00
# 8     Apartment  White         1200                1   $6,250.00
# 9     farmhouse  White         2504                4   $9,700.00

# %%
import pandas as pd
data_frame = pd.read_csv('E:\College stuff\Sem 5\Club\Workshop 1\workshop-1\house-sales.csv')
cross_tab = pd.crosstab(data_frame['Type of house'], data_frame['Number of doors'])
print(cross_tab)
# Out:
# Number of doors  1  2  3  4
# Type of house
# Apartment        1  0  0  0
# Duplex           0  1  0  0
# Farmhouse        0  0  1  0
# apartment        2  1  0  0
# bungalow         0  0  0  1
# duplex           0  2  0  0
# farmhouse        0  0  0  1

# %%
import pandas as pd
data_frame = pd.read_csv('E:\College stuff\Sem 5\Club\Workshop 1\workshop-1\house-sales.csv')
columns_to_drop = ['Colour', 'Price']
data_frame_dropped = data_frame.drop(columns_to_drop, axis=1)
average_by_group = data_frame.groupby('Type of house').mean()
print(average_by_group)
# Out:
#                Area (sqft)  Number of doors
# Type of house
# Apartment      1200.000000         1.000000
# Duplex          502.000000         2.000000
# Farmhouse      2020.000000         3.000000
# apartment      1146.666667         1.333333
# bungalow       1500.000000         4.000000
# duplex          540.000000         2.000000
# farmhouse      2504.000000         4.000000
# C:\Users\Preetam Kalyaan\AppData\Local\Temp\ipykernel_37136\1235142626.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   average_by_group = data_frame.groupby('Type of house').mean()

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
data_frame = pd.read_csv('E:\College stuff\Sem 5\Club\Workshop 1\workshop-1\house-sales.csv')
column_data = data_frame['Area (sqft)']
plt.plot(column_data)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Area (sqft)')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
data_frame = pd.read_csv('E:\College stuff\Sem 5\Club\Workshop 1\workshop-1\house-sales.csv')
column_data = data_frame['Area (sqft)']
plt.hist(column_data)
plt.xlabel('Bins')
plt.ylabel('Frequency')
plt.title('Area (sqft)')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
data_frame = pd.read_csv('E:\College stuff\Sem 5\Club\Workshop 1\workshop-1\house-sales.csv')
column_data = data_frame['Price']
column_data.plot()
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Price')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 6
#       4 data_frame = pd.read_csv('E:\College stuff\Sem 5\Club\Workshop 1\workshop-1\house-sales.csv')
#       5 column_data = data_frame['Price']
# ----> 6 column_data.plot()
#       7 plt.xlabel('X-axis')
#       8 plt.ylabel('Y-axis')
#
# File ~\anaconda3\lib\site-packages\pandas\plotting\_core.py:1000, in PlotAccessor.__call__(self, *args, **kwargs)
#     997             label_name = label_kw or data.columns
#     998             data.columns = label_name
# -> 1000 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
data_frame = pd.read_csv('E:\College stuff\Sem 5\Club\Workshop 1\workshop-1\house-sales.csv')
data_frame["Price"] = data_frame["Price"].str.replace('[\$\,]|\.\d*', '').astype(int)
column_data = data_frame['Price']
column_data.plot()
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Price')
plt.show()
# Out:
# C:\Users\Preetam Kalyaan\AppData\Local\Temp\ipykernel_37136\4292321026.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   data_frame["Price"] = data_frame["Price"].str.replace('[\$\,]|\.\d*', '').astype(int)

# %%
import pandas as pd
data_frame = pd.read_csv('E:\College stuff\Sem 5\Club\Workshop 1\workshop-1\house-sales.csv')
data_frame["Price"] = data_frame["Price"].str.replace('[\$\,]|\.\d*', '').astype(int)
column_data = data_frame['Price']
print(column_data)
# Out:
# 0     4000
# 1     5000
# 2     7000
# 3    22000
# 4     3500
# 5     4500
# 6     7500
# 7     7000
# 8     6250
# 9     9700
# Name: Price, dtype: int32
# C:\Users\Preetam Kalyaan\AppData\Local\Temp\ipykernel_37136\200562718.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   data_frame["Price"] = data_frame["Price"].str.replace('[\$\,]|\.\d*', '').astype(int)

# %%
import pandas as pd
data_frame = pd.read_csv('E:\College stuff\Sem 5\Club\Workshop 1\workshop-1\house-sales.csv')
data_frame['Price'] = data_frame['Price'].astype(str).str.rstrip('00')

# %%
import pandas as pd
data_frame = pd.read_csv('E:\College stuff\Sem 5\Club\Workshop 1\workshop-1\house-sales.csv')
data_frame['Price'] = data_frame['Price'].astype(str).str.rstrip('00')
column_data = data_frame['Price']
print(column_data)
# Out:
# 0     $4,000.
# 1     $5,000.
# 2     $7,000.
# 3    $22,000.
# 4     $3,500.
# 5     $4,500.
# 6     $7,500.
# 7     $7,000.
# 8     $6,250.
# 9     $9,700.
# Name: Price, dtype: object

# %%
import pandas as pd
data_frame = pd.read_csv('E:\College stuff\Sem 5\Club\Workshop 1\workshop-1\house-sales.csv')
data_frame["Price"] = data_frame["Price"].str.replace('[\$\,]|\.\d*', '').astype(int)
column_data = data_frame['Price']
print(column_data)
# Out:
# 0     4000
# 1     5000
# 2     7000
# 3    22000
# 4     3500
# 5     4500
# 6     7500
# 7     7000
# 8     6250
# 9     9700
# Name: Price, dtype: int32
# C:\Users\Preetam Kalyaan\AppData\Local\Temp\ipykernel_37136\925223533.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   data_frame["Price"] = data_frame["Price"].str.replace('[\$\,]|\.\d*', '').astype(int)

# %%
import pandas as pd
data_frame = pd.read_csv('E:\College stuff\Sem 5\Club\Workshop 1\workshop-1\house-sales.csv')
data_frame['Type of house'] = data_frame['Type of house'].str.lower()
column_data = data_frame['Type of house']
print(column_data)
print(data_frame)
# Out:
# 0    apartment
# 1       duplex
# 2    apartment
# 3     bungalow
# 4    farmhouse
# 5    apartment
# 6       duplex
# 7       duplex
# 8    apartment
# 9    farmhouse
# Name: Type of house, dtype: object
#   Type of house Colour  Area (sqft)  Number of doors       Price
# 0     apartment  White         1100                1   $4,000.00
# 1        duplex    Red          502                2   $5,000.00
# 2     apartment   Blue         1225                2   $7,000.00
# 3      bungalow  Black         1500                4  $22,000.00
# 4     farmhouse  White         2020                3   $3,500.00
# 5     apartment  Green         1115                1   $4,500.00
# 6        duplex   Blue          550                2   $7,500.00
# 7        duplex   Blue          530                2   $7,000.00
# 8     apartment  White         1200                1   $6,250.00
# 9     farmhouse  White         2504                4   $9,700.00

# %%
import pandas as pd
data_frame = pd.read_csv('E:\College stuff\Sem 5\Club\Workshop 1\workshop-1\house-missing-data.csv')
print(data_frame)
# Out:
#    Type of house Colour  Area (sqft)  Number of doors       Price
# 0      apartment  White       1100.0              1.0   $4,000.00
# 1         duplex    Red        502.0              2.0   $5,000.00
# 2      apartment   Blue          NaN              2.0   $7,000.00
# 3       bungalow  Black       1500.0              4.0  $22,000.00
# 4      farmhouse  White       2020.0              3.0   $3,500.00
# 5      apartment  Green          NaN              1.0   $4,500.00
# 6         duplex    NaN          NaN              2.0   $7,500.00
# 7         duplex   Blue          NaN              2.0   $7,000.00
# 8      apartment  White          NaN              1.0         NaN
# 9      farmhouse  White       1200.0              NaN         NaN
# 10           NaN  White       2504.0              4.0   $7,500.00

# %%
import pandas as pd
data_frame = pd.read_csv('E:\College stuff\Sem 5\Club\Workshop 1\workshop-1\house-missing-data.csv')
data_frame_filled = data_frame.fillna(data_frame.mean())
print(data_frame_filled)
# Out:
#    Type of house Colour  Area (sqft)  Number of doors       Price
# 0      apartment  White       1100.0              1.0   $4,000.00
# 1         duplex    Red        502.0              2.0   $5,000.00
# 2      apartment   Blue       1471.0              2.0   $7,000.00
# 3       bungalow  Black       1500.0              4.0  $22,000.00
# 4      farmhouse  White       2020.0              3.0   $3,500.00
# 5      apartment  Green       1471.0              1.0   $4,500.00
# 6         duplex    NaN       1471.0              2.0   $7,500.00
# 7         duplex   Blue       1471.0              2.0   $7,000.00
# 8      apartment  White       1471.0              1.0         NaN
# 9      farmhouse  White       1200.0              2.2         NaN
# 10           NaN  White       2504.0              4.0   $7,500.00
# ...

# %%
import pandas as pd
data_frame = pd.read_csv('E:\College stuff\Sem 5\Club\Workshop 1\workshop-1\house-missing-data.csv')
data_frame_filled = data_frame.fillna(data_frame.mean())
data_frame['Number of rooms'] = 3
print(data_frame)
# Out:
#    Type of house Colour  Area (sqft)  Number of doors       Price  \
# 0      apartment  White       1100.0              1.0   $4,000.00
# 1         duplex    Red        502.0              2.0   $5,000.00
# 2      apartment   Blue          NaN              2.0   $7,000.00
# 3       bungalow  Black       1500.0              4.0  $22,000.00
# 4      farmhouse  White       2020.0              3.0   $3,500.00
# 5      apartment  Green          NaN              1.0   $4,500.00
# 6         duplex    NaN          NaN              2.0   $7,500.00
# 7         duplex   Blue          NaN              2.0   $7,000.00
# 8      apartment  White          NaN              1.0         NaN
# 9      farmhouse  White       1200.0              NaN         NaN
# 10           NaN  White       2504.0              4.0   $7,500.00
#
#     Number of rooms
# 0                 3
# 1                 3
# 2                 3
# 3                 3
# 4                 3
# 5                 3
# 6                 3
# ...

# %%
import pandas as pd
import numpy as np
data_frame = pd.read_csv('E:\College stuff\Sem 5\Club\Workshop 1\workshop-1\house-missing-data.csv')
data_frame['Shops Nearby'] = data_frame.apply(lambda _: np.random.randint(1, 5), axis=1)
print(data_frame)
# Out:
#    Type of house Colour  Area (sqft)  Number of doors       Price  \
# 0      apartment  White       1100.0              1.0   $4,000.00
# 1         duplex    Red        502.0              2.0   $5,000.00
# 2      apartment   Blue          NaN              2.0   $7,000.00
# 3       bungalow  Black       1500.0              4.0  $22,000.00
# 4      farmhouse  White       2020.0              3.0   $3,500.00
# 5      apartment  Green          NaN              1.0   $4,500.00
# 6         duplex    NaN          NaN              2.0   $7,500.00
# 7         duplex   Blue          NaN              2.0   $7,000.00
# 8      apartment  White          NaN              1.0         NaN
# 9      farmhouse  White       1200.0              NaN         NaN
# 10           NaN  White       2504.0              4.0   $7,500.00
#
#     Shops Nearby
# 0              2
# 1              1
# 2              2
# 3              4
# 4              3
# 5              1
# 6              3
# 7              4
# ...

# %%
data_frame = data_frame.drop(data_frame.columns[-1], axis=1)
print(data_frame)
# Out:
#    Type of house Colour  Area (sqft)  Number of doors       Price
# 0      apartment  White       1100.0              1.0   $4,000.00
# 1         duplex    Red        502.0              2.0   $5,000.00
# 2      apartment   Blue          NaN              2.0   $7,000.00
# 3       bungalow  Black       1500.0              4.0  $22,000.00
# 4      farmhouse  White       2020.0              3.0   $3,500.00
# 5      apartment  Green          NaN              1.0   $4,500.00
# 6         duplex    NaN          NaN              2.0   $7,500.00
# 7         duplex   Blue          NaN              2.0   $7,000.00
# 8      apartment  White          NaN              1.0         NaN
# 9      farmhouse  White       1200.0              NaN         NaN
# 10           NaN  White       2504.0              4.0   $7,500.00

# %%
shuffled_data_frame = data_frame.sample(frac=1)
print(shuffled_data_frame)
# Out:
#    Type of house Colour  Area (sqft)  Number of doors       Price
# 7         duplex   Blue          NaN              2.0   $7,000.00
# 3       bungalow  Black       1500.0              4.0  $22,000.00
# 6         duplex    NaN          NaN              2.0   $7,500.00
# 10           NaN  White       2504.0              4.0   $7,500.00
# 5      apartment  Green          NaN              1.0   $4,500.00
# 0      apartment  White       1100.0              1.0   $4,000.00
# 9      farmhouse  White       1200.0              NaN         NaN
# 4      farmhouse  White       2020.0              3.0   $3,500.00
# 8      apartment  White          NaN              1.0         NaN
# 1         duplex    Red        502.0              2.0   $5,000.00
# 2      apartment   Blue          NaN              2.0   $7,000.00

# %%
shuffled_data_frame = shuffled_data_frame.reset_index(drop=True)
print(shuffled_data_frame)
# Out:
#    Type of house Colour  Area (sqft)  Number of doors       Price
# 0         duplex   Blue          NaN              2.0   $7,000.00
# 1       bungalow  Black       1500.0              4.0  $22,000.00
# 2         duplex    NaN          NaN              2.0   $7,500.00
# 3            NaN  White       2504.0              4.0   $7,500.00
# 4      apartment  Green          NaN              1.0   $4,500.00
# 5      apartment  White       1100.0              1.0   $4,000.00
# 6      farmhouse  White       1200.0              NaN         NaN
# 7      farmhouse  White       2020.0              3.0   $3,500.00
# 8      apartment  White          NaN              1.0         NaN
# 9         duplex    Red        502.0              2.0   $5,000.00
# 10     apartment   Blue          NaN              2.0   $7,000.00

# %%
conversion_factor = 0.092903
data_frame['Area (sqft)'] = data_frame['Area (sqft)'].apply(lambda x: x * conversion_factor)
print(data_frame)
# Out:
#    Type of house Colour  Area (sqft)  Number of doors       Price
# 0      apartment  White   102.193300              1.0   $4,000.00
# 1         duplex    Red    46.637306              2.0   $5,000.00
# 2      apartment   Blue          NaN              2.0   $7,000.00
# 3       bungalow  Black   139.354500              4.0  $22,000.00
# 4      farmhouse  White   187.664060              3.0   $3,500.00
# 5      apartment  Green          NaN              1.0   $4,500.00
# 6         duplex    NaN          NaN              2.0   $7,500.00
# 7         duplex   Blue          NaN              2.0   $7,000.00
# 8      apartment  White          NaN              1.0         NaN
# 9      farmhouse  White   111.483600              NaN         NaN
# 10           NaN  White   232.629112              4.0   $7,500.00

# %%
data_frame = data_frame.rename(columns={'Area (sqft)': 'Area (sqm)'})
print(data_frame)
# Out:
#    Type of house Colour  Area (sqm)  Number of doors       Price
# 0      apartment  White  102.193300              1.0   $4,000.00
# 1         duplex    Red   46.637306              2.0   $5,000.00
# 2      apartment   Blue         NaN              2.0   $7,000.00
# 3       bungalow  Black  139.354500              4.0  $22,000.00
# 4      farmhouse  White  187.664060              3.0   $3,500.00
# 5      apartment  Green         NaN              1.0   $4,500.00
# 6         duplex    NaN         NaN              2.0   $7,500.00
# 7         duplex   Blue         NaN              2.0   $7,000.00
# 8      apartment  White         NaN              1.0         NaN
# 9      farmhouse  White  111.483600              NaN         NaN
# 10           NaN  White  232.629112              4.0   $7,500.00
